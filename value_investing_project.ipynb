# %%
# !pip install yfinance
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\gharr\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import yfinance as yf
from stock_class import Stock
from funcs import file_read
tickers = file_read('test_run - Sheet1.csv')

new_list = sorted(tickers, key=lambda x: x.rank_score, reverse=True)

for i in new_list:
    print("Stock Ticker - ", i.ticker, " score is  ", i.rank_score)
# Out:
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: WBA"}}}
# Stock Ticker -  CNC  score is   832.7684287254425
# Stock Ticker -  CVS  score is   395.33930063523945
# Stock Ticker -  F  score is   384.07021124148423
# Stock Ticker -  KR  score is   355.7038184117197
# Stock Ticker -  BG  score is   342.0220343607952
# Stock Ticker -  ADM  score is   297.4065066887385
# Stock Ticker -  BBY  score is   295.9987606851636
# Stock Ticker -  HPQ  score is   271.0228164498307
# Stock Ticker -  MPC  score is   263.4393919998522
# Stock Ticker -  LYB  score is   257.52246535984705
# Stock Ticker -  GM  score is   257.05240346994395
# Stock Ticker -  PSX  score is   248.57778247842614
# Stock Ticker -  TGT  score is   239.71711482803582
# Stock Ticker -  VLO  score is   223.77501307851318
# Stock Ticker -  LKQ  score is   192.73832311135197
# Stock Ticker -  MHK  score is   159.10978334934947
# ...

# %%
import pandas as pd

rows = []

for stock in new_list:
    rows.append({
        "Ticker": stock.ticker,
        "Rank Score": stock.rank_score,
        "Revenue_to_EV_%": stock.rev_toEV,
        "Profit_Margin_%": stock.profit_margin,
        "Return_on_EV_%": stock.return_on_EV,
        "2yr_Revenue_Growth_%": stock.twoyr_growth,
        "Enterprise_Value": stock.get_enterprise_value(),
        "Market_Cap": stock.market_cap,
        "Eligible": stock.eligible
    })

df = pd.DataFrame(rows)

df.to_csv("value_rankings.csv", index=False)
df.head(10)
# Out:
#   Ticker  Rank Score  Revenue_to_EV_%  Profit_Margin_%  Return_on_EV_%  \
# 0    CNC  832.768429           900.90           -3.155           -3.53
# 1    CVS  395.339301           228.31            0.120          364.75
# 2      F  384.070211           102.99            2.482           39.11
# 3     KR  355.703818           216.45            0.536           86.14
# 4     BG  342.022034           180.18            2.201           25.22
# 5    ADM  297.406507           232.02            1.429           30.16
# 6    BBY  295.998761           245.70            1.542           26.42
# 7    HPQ  271.022816           200.00            4.574           10.93
# 8    MPC  263.439392           153.14            2.158           30.26
# 9    LYB  257.522465           147.71           -3.198          -21.18
#
#    2yr_Revenue_Growth_%  Enterprise_Value    Market_Cap  Eligible
# 0                  6.41      1.867897e+10  2.022597e+10      True
# ...

# %%
new_list[0].get_enterprise_value()
# Out:
# 18678966272
